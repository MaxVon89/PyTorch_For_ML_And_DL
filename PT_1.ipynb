# %% [markdown]
# # PyTorch
#
#     Started as Torch lib for Dart at Facebook (now Meta), now open-source
#
#     Fast DL, ML code
#
#     Access to prebuilt models (TorchHub)
#
#
# ##### PyTorch, hereinafter as 'PT'

# %%
import torch

# %% [markdown]
# ### PT
#     Allows code to be able to run on a GPU or a TPU using CUDA
#     Most commonly on GPU

# %% [markdown]
# ### GPU:
#     Graphics Processing Unit
#
#
# ### TPU:
#     Tensor Processing Unit

# %% [markdown]
# ## _"But what is a TENSOR?"_

# %%
# A tensor is any rep. of numbers
# Usually numerical rep. of everyday things

# %% [markdown]
# ## Tensors are multidemsional arrays
#
# #### However,
#     There is a hierarchy in rep. of numbers (tensors)
#
#     Scalar: 0 dimensional
#     Vector: 1 dimensional   ... ex.: (1,2)
#     Matrix: 2 dimensional   ... ex.: ([1,2],[3,4])
